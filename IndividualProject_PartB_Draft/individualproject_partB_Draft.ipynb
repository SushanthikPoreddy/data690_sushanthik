# %% [markdown]
# <a href="https://colab.research.google.com/github/SushanthikPoreddy/data690_sushanthik/blob/main/IndividualProject_PartB_Draft/individualproject_partB_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("/content/wdi_data (3).csv")
df.head()
# Out:
#    Unnamed: 0  Year        value  ...      Region         Income Group Lending Type
# 0           0  2015  3555.505260  ...  South Asia  Lower middle income          IDA
# 1           1  2016  3848.957664  ...  South Asia  Lower middle income          IDA
# 2           2  2017  4160.703325  ...  South Asia  Lower middle income          IDA
# 3           3  2018  4547.479572  ...  South Asia  Lower middle income          IDA
# 4           4  2019  4954.761400  ...  South Asia  Lower middle income          IDA
#
# [5 rows x 9 columns]

# %% [markdown]
# ## GDP per capita by year in different countries:

# %%
df_GDP = df.query('indicator == "NY.GDP.PCAP.PP.CD"')
df_GDP.head(10)
# Out:
#    Unnamed: 0  Year  ...         Income Group Lending Type
# 0           0  2015  ...  Lower middle income          IDA
# 1           1  2016  ...  Lower middle income          IDA
# 2           2  2017  ...  Lower middle income          IDA
# 3           3  2018  ...  Lower middle income          IDA
# 4           4  2019  ...  Lower middle income          IDA
# 5           5  2020  ...  Lower middle income          IDA
# 6           6  2015  ...  Upper middle income         IBRD
# 7           7  2016  ...  Upper middle income         IBRD
# 8           8  2017  ...  Upper middle income         IBRD
# 9           9  2018  ...  Upper middle income         IBRD
#
# [10 rows x 9 columns]

# %%
df_GDP.drop(columns = ["Unnamed: 0"], inplace=True)
df_GDP.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Year         value  ...         Income Group Lending Type
# 0  2015   3555.505260  ...  Lower middle income          IDA
# 1  2016   3848.957664  ...  Lower middle income          IDA
# 2  2017   4160.703325  ...  Lower middle income          IDA
# 3  2018   4547.479572  ...  Lower middle income          IDA
# 4  2019   4954.761400  ...  Lower middle income          IDA
# 5  2020   5082.680750  ...  Lower middle income          IDA
# 6  2015  12978.768911  ...  Upper middle income         IBRD
# 7  2016  13572.619989  ...  Upper middle income         IBRD
# 8  2017  14344.421239  ...  Upper middle income         IBRD
# 9  2018  15608.967069  ...  Upper middle income         IBRD
#
# [10 rows x 8 columns]

# %%
df_pivot1 = df_GDP.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'],columns = 'indicator', values ='value').reset_index()
df_pivot1.reset_index().head()
# Out:
# indicator  index  Year  ...    Lending Type NY.GDP.PCAP.PP.CD
# 0              0  2015  ...             IDA       3555.505260
# 1              1  2015  ...            IBRD      12978.768911
# 2              2  2015  ...  Not classified      34903.127478
# 3              3  2015  ...  Not classified      42567.591797
# 4              4  2015  ...            IBRD       5464.859178
#
# [5 rows x 8 columns]

# %%
fig = px.line(
    df_pivot1, 
    x="Year", 
    y="NY.GDP.PCAP.PP.CD",
    labels={"NY.GDP.PCAP.PP.CD":"GDP per capita, PPP (current international $)"},
    hover_name='Country Name',
    color='Country Name'
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e1130772-a8dc-4014-9faf-fb38e6154cac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1130772-a8dc-4014-9faf-fb38e6154cac")) {
#                     Plotly.newPlot(
#                         'e1130772-a8dc-4014-9faf-fb38e6154cac',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Bangladesh<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["Bangladesh", "Bangladesh", "Bangladesh", "Bangladesh", "Bangladesh", "Bangladesh"], "legendgroup": "Country Name=Bangladesh", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Country Name=Bangladesh", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [3555.505259706, 3848.9576636919, 4160.7033247153, 4547.4795716194, 4954.7614000529, 5082.6807503643], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=China<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["China", "China", "China", "China", "China", "China"], "legendgroup": "Country Name=China", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Country Name=China", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [12978.7689105655, 13572.6199886994, 14344.4212394424, 15608.9670692513, 16772.8431692214, 17311.9979202848], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Spain<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["Spain", "Spain", "Spain", "Spain", "Spain", "Spain"], "legendgroup": "Country Name=Spain", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Country Name=Spain", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [34903.1274779473, 37286.2134326488, 39528.925387266805, 40720.1908040246, 42185.5861192043, 38334.6113444231], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United Kingdom<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["United Kingdom", "United Kingdom", "United Kingdom", "United Kingdom", "United Kingdom", "United Kingdom"], "legendgroup": "Country Name=United Kingdom", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Country Name=United Kingdom", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [42567.5917974837, 44149.9999768118, 45744.7104907571, 47145.8840978145, 48513.497502193604, 44916.2283385249], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=India<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["India", "India", "India", "India", "India", "India"], "legendgroup": "Country Name=India", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [5464.859178008, 5839.8648167547, 6182.922108574699, 6675.3612941094, 6997.8639882409, 6454.347356381801], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United States<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["United States", "United States", "United States", "United States", "United States", "United States"], "legendgroup": "Country Name=United States", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "Country Name=United States", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [56863.3714957652, 58021.4004997125, 60109.6557260477, 63064.418409672806, 65279.529026095, 63543.577788724004], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinew

# %% [markdown]
# ## Mortality rate due to unsafe water, unsafe sanitation, and lack of hygiene in different countries:

# %%
df_2016 = df.query("Year == 2016")
df_2016.sample(10)
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 7            7  2016  ...  Upper middle income            IBRD
# 53          53  2016  ...          High income  Not classified
# 49          49  2016  ...  Upper middle income            IBRD
# 19          19  2016  ...          High income  Not classified
# 48          48  2016  ...  Lower middle income             IDA
# 85          85  2016  ...          High income  Not classified
# 55          55  2016  ...  Lower middle income             IDA
# 25          25  2016  ...          High income  Not classified
# 67          67  2016  ...  Lower middle income            IBRD
# 51          51  2016  ...          High income  Not classified
#
# [10 rows x 9 columns]

# %%
df_2016 = df_2016[df_2016["indicator"].isin(['SH.STA.WASH.P5'])]
df_2016.head()
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 48          48  2016  ...  Lower middle income             IDA
# 49          49  2016  ...  Upper middle income            IBRD
# 50          50  2016  ...  Lower middle income            IBRD
# 51          51  2016  ...          High income  Not classified
# 52          52  2016  ...          High income  Not classified
#
# [5 rows x 9 columns]

# %%
df_2016.drop(columns = ["Unnamed: 0","Year"], inplace=True)
df_2016.head(10)
# Out:
#     value       indicator  ...         Income Group    Lending Type
# 48   11.9  SH.STA.WASH.P5  ...  Lower middle income             IDA
# 49    0.6  SH.STA.WASH.P5  ...  Upper middle income            IBRD
# 50   18.6  SH.STA.WASH.P5  ...  Lower middle income            IBRD
# 51    0.2  SH.STA.WASH.P5  ...          High income  Not classified
# 52    0.2  SH.STA.WASH.P5  ...          High income  Not classified
# 53    0.2  SH.STA.WASH.P5  ...          High income  Not classified
#
# [6 rows x 7 columns]

# %%
df_pivot = df_2016.pivot(index =['Country Code','Country Name','Region','Income Group','Lending Type'],columns = 'indicator', values ='value').reset_index()
df_pivot.reset_index().head()
# Out:
# indicator  index Country Code  ...    Lending Type SH.STA.WASH.P5
# 0              0          BGD  ...             IDA           11.9
# 1              1          CHN  ...            IBRD            0.6
# 2              2          ESP  ...  Not classified            0.2
# 3              3          GBR  ...  Not classified            0.2
# 4              4          IND  ...            IBRD           18.6
#
# [5 rows x 7 columns]

# %%
fig = px.bar(
    df_pivot,
    x="Country Name",
    y="SH.STA.WASH.P5",
    labels={"SH.STA.WASH.P5":"2016Mortality rate attributed to unsafe water, unsafe sanitation, and lack of hygiene (per 100,000 population)"},
    color="Country Name"
)
fig.update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2b854db3-9faa-4f47-8d4f-04a1a09accaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2b854db3-9faa-4f47-8d4f-04a1a09accaf")) {
#                     Plotly.newPlot(
#                         '2b854db3-9faa-4f47-8d4f-04a1a09accaf',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2016Mortality rate attributed to unsafe water, unsafe sanitation, and lack of hygiene (per 100,000 population)=%{y}", "legendgroup": "Country Name=Bangladesh", "marker": {"color": "#636efa"}, "name": "Country Name=Bangladesh", "offsetgroup": "Country Name=Bangladesh", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bangladesh"], "xaxis": "x", "y": [11.9], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2016Mortality rate attributed to unsafe water, unsafe sanitation, and lack of hygiene (per 100,000 population)=%{y}", "legendgroup": "Country Name=China", "marker": {"color": "#EF553B"}, "name": "Country Name=China", "offsetgroup": "Country Name=China", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["China"], "xaxis": "x", "y": [0.6000000000000001], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2016Mortality rate attributed to unsafe water, unsafe sanitation, and lack of hygiene (per 100,000 population)=%{y}", "legendgroup": "Country Name=Spain", "marker": {"color": "#00cc96"}, "name": "Country Name=Spain", "offsetgroup": "Country Name=Spain", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Spain"], "xaxis": "x", "y": [0.2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2016Mortality rate attributed to unsafe water, unsafe sanitation, and lack of hygiene (per 100,000 population)=%{y}", "legendgroup": "Country Name=United Kingdom", "marker": {"color": "#ab63fa"}, "name": "Country Name=United Kingdom", "offsetgroup": "Country Name=United Kingdom", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United Kingdom"], "xaxis": "x", "y": [0.2], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2016Mortality rate attributed to unsafe water, unsafe sanitation, and lack of hygiene (per 100,000 population)=%{y}", "legendgroup": "Country Name=India", "marker": {"color": "#FFA15A"}, "name": "Country Name=India", "offsetgroup": "Country Name=India", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["India"], "xaxis": "x", "y": [18.6], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>2016Mortality rate attributed to unsafe water, unsafe sanitation, and lack of hygiene (per 100,000 population)=%{y}", "legendgroup": "Country Name=United States", "marker": {"color": "#19d3f3"}, "name": "Country Name=United States", "offsetgroup": "Country Name=United States", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["United States"], "xaxis": "x", "y": [0.2], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %% [markdown]
# ## How does mortality rate relate with total population and number of deaths that are caused by the communicable diseases?

# %%
df_Deaths = df.query('indicator == "SH.DTH.COMM.ZS"')
df_Deaths.head(10)
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 36          36  2015  ...  Lower middle income             IDA
# 37          37  2019  ...  Lower middle income             IDA
# 38          38  2015  ...  Upper middle income            IBRD
# 39          39  2019  ...  Upper middle income            IBRD
# 40          40  2015  ...  Lower middle income            IBRD
# 41          41  2019  ...  Lower middle income            IBRD
# 42          42  2015  ...          High income  Not classified
# 43          43  2019  ...          High income  Not classified
# 44          44  2015  ...          High income  Not classified
# 45          45  2019  ...          High income  Not classified
#
# [10 rows x 9 columns]

# %%
df_Deaths.drop(columns = ["Unnamed: 0"], inplace=True)
df_Deaths.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Year      value  ...         Income Group    Lending Type
# 36  2015  28.807663  ...  Lower middle income             IDA
# 37  2019  22.612837  ...  Lower middle income             IDA
# 38  2015   4.132797  ...  Upper middle income            IBRD
# 39  2019   3.549711  ...  Upper middle income            IBRD
# 40  2015  28.260253  ...  Lower middle income            IBRD
# 41  2019  24.166184  ...  Lower middle income            IBRD
# 42  2015   5.324214  ...          High income  Not classified
# 43  2019   5.610445  ...          High income  Not classified
# 44  2015   8.066941  ...          High income  Not classified
# 45  2019   8.156775  ...          High income  Not classified
#
# [10 rows x 8 columns]

# %%
df_pivot2 = df_Deaths.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'],columns = 'indicator', values ='value').reset_index()
df_pivot2.reset_index().head()
# Out:
# indicator  index  Year  ...    Lending Type SH.DTH.COMM.ZS
# 0              0  2015  ...             IDA      28.807663
# 1              1  2015  ...            IBRD       4.132797
# 2              2  2015  ...  Not classified       5.324214
# 3              3  2015  ...  Not classified       8.066941
# 4              4  2015  ...            IBRD      28.260253
#
# [5 rows x 8 columns]

# %%
fig = px.line(
    df_pivot2,
    x="Year", 
    y="SH.DTH.COMM.ZS",
    color='Country Name',
    labels={"SH.DTH.COMM.ZS":"Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)"}
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ffa33d0-7949-4162-96eb-9bd7477dfbb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ffa33d0-7949-4162-96eb-9bd7477dfbb1")) {
#                     Plotly.newPlot(
#                         '1ffa33d0-7949-4162-96eb-9bd7477dfbb1',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Bangladesh<br>Year=%{x}<br>Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)=%{y}", "legendgroup": "Country Name=Bangladesh", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Country Name=Bangladesh", "showlegend": true, "type": "scatter", "x": [2015, 2019], "xaxis": "x", "y": [28.807663075100002, 22.612837223400003], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=China<br>Year=%{x}<br>Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)=%{y}", "legendgroup": "Country Name=China", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Country Name=China", "showlegend": true, "type": "scatter", "x": [2015, 2019], "xaxis": "x", "y": [4.1327971245, 3.5497105577999997], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Spain<br>Year=%{x}<br>Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)=%{y}", "legendgroup": "Country Name=Spain", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Country Name=Spain", "showlegend": true, "type": "scatter", "x": [2015, 2019], "xaxis": "x", "y": [5.324213744200001, 5.6104446648], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=United Kingdom<br>Year=%{x}<br>Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)=%{y}", "legendgroup": "Country Name=United Kingdom", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Country Name=United Kingdom", "showlegend": true, "type": "scatter", "x": [2015, 2019], "xaxis": "x", "y": [8.0669410656, 8.156775141], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=India<br>Year=%{x}<br>Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)=%{y}", "legendgroup": "Country Name=India", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [2015, 2019], "xaxis": "x", "y": [28.2602532026, 24.1661843666], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=United States<br>Year=%{x}<br>Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)=%{y}", "legendgroup": "Country Name=United States", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "Country Name=United States", "showlegend": true, "type": "scatter", "x": [2015, 2019], "xaxis": "x", "y": [5.6512033275, 5.3020598008999995], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
df_2015 = df.query("Year == 2015")
df_2015.sample(10)
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 24          24  2015  ...          High income  Not classified
# 44          44  2015  ...          High income  Not classified
# 36          36  2015  ...  Lower middle income             IDA
# 54          54  2015  ...  Lower middle income             IDA
# 42          42  2015  ...          High income  Not classified
# 78          78  2015  ...          High income  Not classified
# 18          18  2015  ...          High income  Not classified
# 84          84  2015  ...          High income  Not classified
# 66          66  2015  ...  Lower middle income            IBRD
# 6            6  2015  ...  Upper middle income            IBRD
#
# [10 rows x 9 columns]

# %%
df_2015.drop(columns = ["Unnamed: 0","Year" ],inplace=True)
df_2015.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            value          indicator  ...         Income Group    Lending Type
# 0    3555.505260  NY.GDP.PCAP.PP.CD  ...  Lower middle income             IDA
# 6   12978.768911  NY.GDP.PCAP.PP.CD  ...  Upper middle income            IBRD
# 12   5464.859178  NY.GDP.PCAP.PP.CD  ...  Lower middle income            IBRD
# 18  34903.127478  NY.GDP.PCAP.PP.CD  ...          High income  Not classified
# 24  42567.591797  NY.GDP.PCAP.PP.CD  ...          High income  Not classified
# 30  56863.371496  NY.GDP.PCAP.PP.CD  ...          High income  Not classified
# 36     28.807663     SH.DTH.COMM.ZS  ...  Lower middle income             IDA
# 38      4.132797     SH.DTH.COMM.ZS  ...  Upper middle income            IBRD
# 40     28.260253     SH.DTH.COMM.ZS  ...  Lower middle income            IBRD
# 42      5.324214     SH.DTH.COMM.ZS  ...          High income  Not classified
#
# [10 rows x 7 columns]

# %%
df_pivot = df_2015.pivot(index =['Country Code','Country Name','Region','Income Group','Lending Type'],columns = 'indicator', values ='value').reset_index()
df_pivot.reset_index().head()
# Out:
# indicator  index Country Code  ... SH.DTH.COMM.ZS   SP.POP.TOTL
# 0              0          BGD  ...      28.807663  1.562563e+08
# 1              1          CHN  ...       4.132797  1.371220e+09
# 2              2          ESP  ...       5.324214  4.644483e+07
# 3              3          GBR  ...       8.066941  6.511622e+07
# 4              4          IND  ...      28.260253  1.310152e+09
#
# [5 rows x 9 columns]

# %%
fig = px.pie(df_pivot, values='SP.POP.TOTL', names='Country Name', title='Total Population',hover_name='Country Name')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="44443c10-03ab-453a-bbca-70318c0bdf45" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("44443c10-03ab-453a-bbca-70318c0bdf45")) {
#                     Plotly.newPlot(
#                         '44443c10-03ab-453a-bbca-70318c0bdf45',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=%{label}<br>SP.POP.TOTL=%{value}", "hovertext": ["Bangladesh", "China", "Spain", "United Kingdom", "India", "United States"], "labels": ["Bangladesh", "China", "Spain", "United Kingdom", "India", "United States"], "legendgroup": "", "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [156256287.0, 1371220000.0, 46444832.0, 65116219.0, 1310152392.0, 320738994.0]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...
